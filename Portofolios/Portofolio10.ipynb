# %%
import pandas as pd
digimon = pd.read_csv('Portofolio4/DigiDB_digimonlist.csv')

# %%
digimonCorrelations = digimon.corr()
digimonCorrelations.style.background_gradient(cmap='coolwarm', axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_f5ccd_row0_col0, #T_f5ccd_row1_col1, #T_f5ccd_row2_col2, #T_f5ccd_row3_col3, #T_f5ccd_row4_col4, #T_f5ccd_row5_col5, #T_f5ccd_row6_col6, #T_f5ccd_row7_col7, #T_f5ccd_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f5ccd_row0_col1, #T_f5ccd_row1_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_f5ccd_row0_col2, #T_f5ccd_row2_col0 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_f5ccd_row0_col3, #T_f5ccd_row3_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_f5ccd_row0_col4, #T_f5ccd_row1_col5, #T_f5ccd_row4_col0, #T_f5ccd_row5_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_f5ccd_row0_col5, #T_f5ccd_row5_col0 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_f5ccd_row0_col6, #T_f5ccd_row1_col4, #T_f5ccd_row4_col1, #T_f5ccd_row6_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# ...

# %%
digimon.plot(kind='scatter', x='Lv50 SP', y='Lv50 Int')
# Out:
# <AxesSubplot:xlabel='Lv50 SP', ylabel='Lv50 Int'>

# %% [markdown]
# ### Intelligence moet je zien als je magic attack. SP moet je zien als je mana, mana heb je nodig om magic attacks te doen
# ### Daarom hebben de sterke magic attackers veel mana en is de positieve correlatie ook logisch
