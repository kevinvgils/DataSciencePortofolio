# %%
import pandas as pd
digimon = pd.read_csv('../Portofolio4/DigiDB_digimonlist.csv')

# %%
digimon['Lv 50 HP'].plot(kind='hist', bins = 15)
### Normal Distrubution
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
digimon['Lv50 Atk'].plot(kind='hist', bins = 15)
### Poisson Distrubution
# Out:
# <AxesSubplot:ylabel='Frequency'>
