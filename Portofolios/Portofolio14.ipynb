# %%
import pandas as pd
import seaborn as sns
digimon = pd.read_csv('Portofolio4/DigiDB_digimonlist.csv')

# %%
def create_contingency_table(dataset, column1, column2):
    return dataset.groupby([column1, column2]).size().unstack(column1, fill_value=0)

# %% [markdown]
# ### Ik verwacht een correlatie tussen Attribute en Type. Het meest logisch is bijvoorbeeld de Types; Virus en Vaccine. Het zou het raar zijn als die digimons dezelfde Attributes zouden hebben over het algemeen omdat het precies het tegenovergestelde is.

# %%
digimonContingencyTable = create_contingency_table(digimon, 'Attribute','Type')
digimonContingencyTable.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Type'>

# %%
from scipy.stats import chi2_contingency
def chi_squared_test(dataset, column1, column2):
    contingency_table = create_contingency_table(dataset, column1, column2)
    chi2 = chi2_contingency(contingency_table)
    p_value = chi2[1]
    odds_of_correlation = 1 - p_value
    print(f"The odds of a correlation between {column1} and {column2} is {odds_of_correlation * 100}% (Based on a p value of {p_value}).")
    print("This percentage needs to be at least 95% for a significant correlation.")

# %%
chi_squared_test(digimon, 'Attribute','Type')
# Out:
# The odds of a correlation between Attribute and Type is 99.9999996953765% (Based on a p value of 3.046235014769864e-09).
# This percentage needs to be at least 95% for a significant correlation.
